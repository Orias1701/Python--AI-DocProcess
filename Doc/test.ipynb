# %%
import PyPDF2
import docx
import re
from typing import List, Dict
import os

# %%
def extract_pdf_headings(pdf_path: str) -> List[Dict[str, str]]:
    """
    Extract headings from a PDF file based on font size and bold attributes.
    Returns a list of dictionaries containing heading text and estimated level.
    """
    headings = []
    try:
        with open(pdf_path, 'rb') as file:
            reader = PyPDF2.PdfReader(file)
            for page in reader.pages:
                # Extract text and formatting (simplified approach)
                text = page.extract_text()
                lines = text.split('\n')
                
                for line in lines:
                    line = line.strip()
                    if not line:
                        continue
                    # Heuristic: Headings are typically short, bold, or larger font
                    # PyPDF2 doesn't directly provide font info, so we use length and content
                    if len(line.split()) < 10 and line.isupper() or re.match(r'^\d+\.?\s', line):
                        headings.append({
                            'text': line,
                            'level': estimate_heading_level(line)
                        })
    except Exception as e:
        print(f"Error processing PDF {pdf_path}: {str(e)}")
    return headings

def extract_docx_headings(docx_path: str) -> List[Dict[str, str]]:
    """
    Extract headings from a DOCX file based on paragraph styles.
    Returns a list of dictionaries containing heading text and level.
    """
    headings = []
    try:
        doc = docx.Document(docx_path)
        for para in doc.paragraphs:
            if para.style.name.startswith('Heading'):
                level = para.style.name.replace('Heading', '').strip()
                if level.isdigit():
                    headings.append({
                        'text': para.text.strip(),
                        'level': int(level)
                    })
            elif para.text.strip() and len(para.text.split()) < 15:
                # Fallback for non-standard heading styles
                if para.runs and any(run.bold or run.font.size for run in para.runs):
                    headings.append({
                        'text': para.text.strip(),
                        'level': estimate_heading_level(para.text)
                    })
    except Exception as e:
        print(f"Error processing DOCX {docx_path}: {str(e)}")
    return headings

def estimate_heading_level(text: str) -> int:
    """
    Estimate heading level based on text characteristics (heuristic).
    Returns an integer representing the heading level (1-6).
    """
    if re.match(r'^\d+\.\s', text):  # e.g., "1. Introduction"
        return 1
    elif re.match(r'^\d+\.\d+\s', text):  # e.g., "1.1 Subheading"
        return 2
    elif text.isupper():
        return 1
    elif len(text.split()) < 5:
        return 2
    return 3  # Default level for other cases

def process_file(file_path: str) -> List[Dict[str, str]]:
    """
    Process a file (PDF or DOCX) and extract its headings.
    """
    _, ext = os.path.splitext(file_path)
    ext = ext.lower()
    
    if ext == '.pdf':
        return extract_pdf_headings(file_path)
    elif ext == '.docx':
        return extract_docx_headings(file_path)
    else:
        raise ValueError(f"Unsupported file format: {ext}")

def main():
    # Example usage
    file_path = input("Enter the path to your PDF or DOCX file: ")
    if not os.path.exists(file_path):
        print("File not found!")
        return
    
    try:
        headings = process_file(file_path)
        print("\nExtracted Headings:")
        for heading in headings:
            print(f"Level {heading['level']}: {heading['text']}")
    except Exception as e:
        print(f"Error: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# Extracted Headings:
# Level 1: UBND THÀNH PHỐ HÀ NỘI
# Level 1: TRƯỜNG ĐH THỦ ĐÔ HÀ NỘI
# Level 1: CỘNG HOÀ XÃ HỘI CHỦ NGHĨA VIỆT NAM
# Level 1: QUYẾT ĐỊNH
# Level 1: HIỆU TRƯỞNG TRƯỜNG ĐẠI HỌC THỦ ĐÔ HÀ NỘI
# Level 1: QUYẾT ĐỊNH:
# Level 1: UBND THÀNH PHỐ HÀ NỘI
# Level 1: THỦ ĐÔ HÀ NỘI
# Level 1: NHỮNG QUY  ĐỊNH CHUNG
# Level 1: 1. Quy chế này quy định chung về tổ chức và quản lý đào tạo trình độ đại học  tại
# Level 1: 2. Quy chế này áp dụng  trong đào tạo theo hình thức chính quy và hình thức vừa
# Level 1: 3. Quy chế này là căn cứ  để xây dựng và ban hành các văn bản quy định cụ thể
# Level 1: 1. Chương trình đào tạo  được xây dựng theo đơn vị tín chỉ, cấu trúc từ các môn
# Level 1: 2. Nội dung , chuẩn đầu ra của  chương trình đào tạo áp dụng  chung đối với  các
# Level 1: 3. Chương trình đào  tạo được công khai đối với người học  trước khi tuyển sinh
# Level 1: 4. Đối với mỗi hình thức đào tạo, chương trình đà o tạo có đầy đủ nội dung nhằm
# Level 1: 5. Thời gian tối đa để sinh viên  hoàn thành khoá học  không vượt quá 02 lần thời
# Level 1: 1. Là phương thức tổ chức đào tạo theo từng lớp học phần, cho phép sinh viên
# Level 1: 2. Sinh viên không đạt một học phần bắt buộc sẽ phải học lại học phần đó hoặc
# Level 1: 3. Sinh viên không đạt một học phần tự chọn sẽ phải học lại học phần đó hoặc
# Level 1: 1. Đào tạo chính quy
# Level 1: 2. Đào tạo  vừa làm vừa học
# Level 1: 3. Đào t ạo liên thông
# Level 1: 4. Đối với  các ngành ưu tiên đào tạo phục vụ nguồn nhân lực phát triển kinh tế  -
# Level 1: 1. Trường  chỉ liên kết đào tạo trình độ đại học theo hình thức vừa làm vừa học
# Level 1: 2. Các yêu cầu tối thiểu đối với việc tổ chức liên  kết đào tạo :
# Level 1: 3. Các yêu cầu tối thiểu của cơ sở phối hợp đào tạo:
# Level 1: 4. Trách nhiệm của các bên tham gia liên kết đào tạo:
# Level 1: LẬP KẾ HOẠCH VÀ TỔ CHỨC GIẢNG DẠY
# Level 1: 1. Kế hoạch giảng dạy và học tập chi tiết  hóa việc tổ chức thực hiện các chương
# Level 1: 2. Kế hoạch năm học thể hiện những mốc thời gian chính của các hoạt động đào
# Level 1: 3. Kế hoạch học kỳ bao gồm kế hoạch mở  lớp, hình thức dạy và học (trực tiếp
# Level 1: 4. Thời  khoá biểu thể hiện thời gian, địa điểm, hoạt động dạy và học  của từng
# Level 1: 5. Trường hợp đặc biệt do Hiệu trưởng  quyết  định.
# Level 1: 1. Trước khi bắt đầu mỗi học kỳ,  sinh viên phải đăng kí học tập  trên hệ thống
# Level 1: 2. Sinh viên phải đăng kí lớp của các  học phần dự địn h sẽ học trong h ọc kỳ,
# Level 1: 1. Đối với sinh viên có học lực bình thường, s ố tín chỉ học tập mà sinh viên phải
# Level 1: 2. Đối với sinh viên có học lực yếu  ở học kì trước , trong học kì tiếp theo, sinh
# Level 1: 3. Không quy định khối lượng học tập tối đa đối với sinh viên khi đăng kí học
# Level 1: 1. Trường  thông báo lịch trình học dự kiến cho từng chương trình trong từng học
# Level 1: 2. Tùy theo khả năng và điều kiện học tập của bản thân, sinh  viên đăng kí lớp học
# Level 1: 3. Trong học kì thứ nhất của khóa học , sinh viên học theo thời khóa biểu do
# Level 1: 4. Việc đă ng kí lớp  học phần trong  từng học kì phải bảo đảm điều kiện tiên
# Level 1: 5. Chậm nhất 01 tuần, sau khi học kì mới bắt đầu , cố vấn  học tập phải thực hiện
# Level 1: 1. Rút bớt học phần trong khối lượng học tập đã đăng kí:
# Level 3: 8 của quy chế này. V iệc rút b ớt học ph ần được thực hiện trong 02  tuần đầu của học
# Level 1: 2. Thủ tục, quy trình  rút bớt các học phần đã đăng kí:
# Level 1: 1. Yêu cầu về tổ chức  giảng dạy :
# Level 1: 2. Dạy và học trực tuyến:
# Level 1: 1. Việc lấy ý kiến phản hồi của người học về nội dung chương trình; phương pháp,
# Level 1: 2. Sinh viên chỉ theo dõi được  kết quả học tập trên cổng thông tin đào tạo  khi đã
# Level 1: 3. Kết quả của việc lấy ý kiến  người học phải đ ược tổng hợp theo khoa và báo cáo
# Level 1: 4. Kết quả khảo sát này là căn cứ để Trường  điều chỉnh nội dung, chương trình đào
# Level 1: 1. Được tham gia vào quá trình  phát triển chương trình; quá trình kiểm tra, đánh giá
# Level 1: 2. Nghiên cứu, phát triển ứng dụng khoa học và chuyển giao công nghệ, b ảo
# Level 1: 3. Học tập, bồi dưỡng nâng cao trình độ lý luận chính trị, chuyên môn, nghiệp vụ
# Level 1: 4. Giữ gìn phẩm chất, uy tín, danh dự của giảng viê n.
# Level 1: 5. Tôn trọng nhân cách của người học, đối xử công bằng với người học, bảo vệ
# Level 1: 6. Tham gia quản lý và giám sát cơ sở giáo dục đại học, tham  gia công tác  Đảng,
# Level 1: 7. Độc lập về quan điểm chuyên môn trong giảng dạy, nghiên cứu khoa học trên
# Level 1: 8. Được bổ nhiệm chức danh của giảng viên, được phong tặng danh hiệu  Nhà
# Level 1: 9. Nhiệm vụ và quyền hạn khác theo quy định của pháp luật có liên quan.
# Level 1: 10. Các hành vi giảng viên không được làm, bao gồm:
# Level 1: 1. Nhiệm vụ và quyền hạn của sinh viên:
# Level 1: 2. Các hành vi sinh viên không được làm :
# Level 1: 1. Sinh viên được đăng kí làm đồ án, khóa luận  hoặc học  thêm một số học phần
# Level 1: 2. Điều kiện, hình thức làm đồ án , khóa luận :
# Level 1: 3. Điểm đồ án , khoá luận  được tính vào điểm trung bình chung tích lũy của toàn
# Level 1: 1. Khối lượng học tập các nội dung thực tập, thực hành, thực tế chuyê n môn
# Level 1: 2. Mỗi chương trình đào tạo  có không quá 04 học phần thực hành, thự c tế
# Level 1: 3. Mỗi đợt thực tập tập trung được tổ chức trong khoảng thời gian từ 04 đến 08
# Level 1: 4. Các khoa đào tạo chịu trách nhiệm xây dựng nội dung học tập, hướng dẫn tổ
# Level 1: 5. Trường hợp đặc biệt do Hiệu trưởng  quyết định.
# Level 1: 1. Đối với mỗi học phần, sinh viên  được đánh giá qua tối thiểu 01 điểm thành
# Level 3: 01 điểm thành phần  và có trọng số  không quá 30%  điểm học phần.
# Level 1: 2. Đối với việc tổ chức b ảo vệ và đánh giá  đồ án, khóa luận chỉ được tổ chức
# Level 1: 3. Điểm học phần được tính từ tổng các điểm thành phần nhân với trọng số
# Level 1: 4. Việc xếp loại các mức điểm A+, A, B+, B, C+, C, D+, D, F được áp dụng cho
# Level 1: 5. Việc xếp loại ở mức điểm F ngoài những  trường hợp như đã nêu ở khoản 4
# Level 1: 6. Việc xếp loại theo mức điểm I được áp dụng cho các trường hợp sau đây:
# Level 1: 7. Việc xếp loại theo mức điểm X được áp dụng đối với những học phần mà
# Level 1: 8. Kí hiệu R được  áp dụng c ho những học phần được công nhận kết quả, khi
# Level 1: 1. Sinh viên có điểm học phần không đạt phải đăng kí học lại theo quy định tại
# Level 1: 2. Sinh viên  có điểm học phần đạt được đăng kí học lại để cải thiện điểm . Sinh
# Level 1: 3. Sau khi có điểm chính thức của học phần, nếu chưa đạt, si nh viên có thể đăng
# Level 1: 4. Sinh viên có nhu cầu có thể  đăng kí học bổ sung  cho đủ khối lượng học tập
# Level 1: 1. Hình thức thi, kiểm tra, đánh giá  có thể là  viết (trắc nghiệm hoặc tự luận), vấn
# Level 1: 2. Trước khi bắt đầu dạy học học phần, giảng viên phải công khai tới sinh viên:
# Level 1: 3. Đối với những học phần có tổ chức thi kết thúc học phần , lịch thi  phải đảm
# Level 1: 4. Thời gian làm bài thi tự luận/trắc nghiệm của mỗi m ôn thi được thực hiện
# Level 1: 5. Đề thi kết thúc học phần phải phù hợp với nội dung học phần đã quy định
# Level 1: 6. Trưởng khoa/trưởng đơn vị tổ chức thi chịu trách  nhiệm phân công cán bộ  coi
# Level 1: 7. Bài chấm thi viết tự luận phải được dọc phách trước khi chấm, việc chấm thi
# Level 1: 8. Trưởng khoa /trưởng đơn vị tổ chức chấm thi  chịu trách nhiệm phân công
# Level 1: 9. Phải có ít nhất 02 cán bộ thực hiện nhập điểm thi kết thúc học phần vào phần
# Level 1: 10. Bài thi kết thúc học phần, kể cả các bài báo cáo thí nghiệm, thực hành; bài
# Level 1: 11. Hình thức tổ chức thi vấn đáp  phải do hai giảng viên thực hiện. Điểm thi vấn
# Level 1: 12. Bản ghi điểm chấm thi kết thúc  học phần phải có đầy đủ chữ kí theo quy
# Level 1: 13. Sinh viên vắng mặt tron g buổi thi, đánh giá không có lý do chính đáng phải
# Level 1: 14. Sinh v iên có nhu cầu  phúc khảo điểm t hi kết thúc học phần nộp đơn về
# Level 1: 1. Kết quả  học tập của sinh viên được đánh giá sau từng học kì , dựa trên kết quả
# Level 1: 2. Để tính điểm trung bình , điểm chữ của học phần được quy đổi về điểm số như
# Level 1: 3. Những điểm chữ không được quy định tại khoản 2  Điều này không được tính
# Level 1: 4. Sinh viên được xếp loại học lực theo điểm trung bình học kỳ, điểm trung bình
# Level 1: 5. Sinh viên được xếp trình độ năm học căn cứ số tín chỉ tích lũy được từ đầu
# Level 1: 6. Các  khoa tổ chức xét tiến độ cho sinh viên và gửi kết quả xét tiến độ về phòng
# Level 1: 1. Cuối  mỗi học kỳ chính, sinh viên được cảnh báo học tập nếu có 02 trong 03
# Level 1: 2. Sinh viên bị buộc thôi học  khi có một trong  các trường hợp  sau:
# Level 1: 3. Quy trình, thủ tục cảnh báo học tập, buộc thôi h ọc: việc thông báo hình thức
# Level 1: 4. Trường hợp sinh viên bị buộc t hôi học, nếu c ó nhu cầu, sinh viên được
# Level 1: 1. Kết quả học tập của người học đ ã tích lũy từ một trình độ đào tạo khác, một
# Level 1: 2. Hội đồng chuyên môn của Trường  xem xét công nhận, chuyển đổi tín chỉ trên
# Level 1: 3. Trường  công khai quy định việc công nhận kết quả học tập và chuy ển đổi tín
# Level 1: 4. Sinh viên  các ngành không chuyên ngoại ngữ có  một trong các chứng chỉ
# Level 1: 5. Sinh viên  các ngành không chuyên ngoại ngữ có một trong các chứng chỉ
# Level 1: 6. Sinh viên  các ngành không chuyên ngoại ngữ có một trong các chứng chỉ
# Level 1: 7. Sinh viên  các ngành chuyên ngoại ngữ có chứ ng chỉ ngoại ngữ quốc tế từ bậc
# Level 3: 3 trở lên được xem xét để miễn học , miễn thi  và thừa nhận kết quả của một số học
# Level 1: 8. Sinh viên đã từng học và tốt nghiệp trình độ trung học phổ thông trở lên ở
# Level 1: 9. Sinh viên không thuộc chuyên ngành công nghệ  thông tin có chứng chỉ ứng
# Level 1: 10. Sinh viên tốt nghiệp trình độ cao đẳng các ngành chuyên công nghệ thông
# Level 1: 1. Sinh viên được xét và công nhận tốt nghiệp k hi có đủ các điều kiện sau:
# Level 1: 2. Những sinh viên đủ điều kiện tốt nghiệp  đã hoàn thành nghĩa vụ tài chính với
# Level 1: 3. Hạng tốt nghiệp được xác định căn cứ vào điểm trung bình tích lũy toà n khoá
# Level 1: 4. Sinh viên đã hết thời gian học tập tối đa theo quy định nhưng chưa đủ điều
# Level 1: 5. Sinh viên không tốt nghiệp được cấp chứng nhận về các học phần đã tích luỹ
# Level 1: 6. Trường  tổ chức xét  tốt nghiệp  ít nhất 03  lần/năm học , dự kiến  vào các thời
# Level 1: 7. Sinh viên hết thời gian học chính quy được chuyển qu a học hình thức vừa làm
# Level 3: 5 Điều 2 của quy chế này.
# Level 1: NHỮNG QUY  ĐỊNH KHÁC  ĐỐI VỚI SINH VIÊN
# Level 1: 1. Sinh viên được  nghỉ học tạm thời và bảo lưu kết quả đã học trong các trường
# Level 1: 2. Thời gian nghỉ học tạm thời vì nhu cầu cá nhân phải được tính vào thời gian
# Level 1: 3. Sinh viên được  thôi học v ì lý do cá nhân  muốn quay trở lại học  tập phải dự
# Level 1: 1. Sinh viên có nhu cầu nghỉ học tạm thời và bảo lưu kết quả học tập đảm bảo
# Level 1: 2. Phòng QLĐT&CTHSSV rà soát các điều kiện và trình Hiệu trưởng  ban hành
# Level 1: 3. Hết thời gian  nghỉ học tạm  thời, sinh viên có nhu cầu quay trở lại học tập
# Level 1: 4. Sinh viên bị kỉ luật đình chỉ học tập, được xem xét quay trở lại học tập, sau
# Level 1: 5. Sinh viên được tiếp nhận học tập trở lại được bố trí vào lớp hành chính  với
# Level 1: 1. Sinh viên được xem xét chuyển sang học một chương trình, một ngành đào
# Level 1: 2. Sinh viên được xem xét chuyển trường  khi có đủ các điều kiện sau :
# Level 1: 3. Sinh viên đ ược xem xét chuyển từ hình thức chính quy sang hình thức vừ a
# Level 1: 4. Thẩm quyền, điều kiện, thủ tục chuyển chương trình, ngành đào tạo, chuyển
# Level 1: 1. Sinh viên của trường Đại học Thủ đô Hà Nội  được học một số học phần tại
# Level 1: 2. Trên cơ sở đánh giá và công nhận lẫn nhau, sinh viên của trường Đại học
# Level 1: 3. Trong hợp tác đào tạo giữa  trường  Đại học Thủ đô Hà Nội  với cơ sở giáo
# Level 1: 1. Sinh viên có thể đăng kí học thêm các học phần của một chương trình khác,
# Level 1: 2. Sinh viên được đ ăng kí học chươn g trình thứ hai sớm nhất khi đã được xếp
# Level 1: 3. Trong quá trình sinh viên học cùng lúc hai chương trình, nếu điểm trung
# Level 1: 4. Thời gian tối đa được phép học đối với sinh viên học cùng lúc hai chương
# Level 1: 5. Sinh viên chỉ được xét tốt nghiệp chương trình thứ hai, nếu có đủ điều kiện
# Level 1: 6. Hàng năm căn cứ tình hình tuyển sinh của các ngành đào tạo, Trường  thông
# Level 1: 7. Sinh viên học chương trình thứ 2 sẽ được bố t rí học cùng các lớp học phần
# Level 1: 1. Người đã  tốt nghiệp các trình độ đào tạo của giáo dục nghề nghiệp được dự
# Level 1: 2. Người đã tốt nghiệp đại học  được dự tuyển và học liên thông để nhận thêm
# Level 1: 3. Người học liên thông thực hiện  chương trình đào tạo và đăng kí học tập  theo
# Level 1: 1. Sinh viên có gi an lận trong thi, kiểm tra, đánh giá kết quả học tập sẽ bị xử lý
# Level 1: 2. Sinh viên thi hộ hoặc nhờ người thi hộ đều bị kỷ luật ở mức đình chỉ học tập
# Level 3: 01 năm đối với trường hợp vi phạm lần thứ nhất và buộc thôi học đối với trường hợp
# Level 1: 3. Người học sử dụng hồ sơ, văn bằng, chứng chỉ giả làm điều kiện  trúng tuyển
# Level 1: TỔ CHỨC THỰC HIỆN
# Level 1: 1. Phòng Quản lí đào tạo và Công tác học sinh sinh viên
# Level 1: 2. Phòng Nhân sự và Kế hoạch -Tài chính
# Level 1: 3. Phòng Quản lí khoa học công nghệ và hợp tác phát triển
# Level 1: 4. Phòng Quản lí chất lượng giáo dục
# Level 1: 5. Văn phòng trường và Trung tâm Khoa học và công nghệ
# Level 1: 6. Trung tâm Khoa học và Công nghệ
# Level 1: 7. Các khoa đào tạo
# Level 1: 1. Trước ngày 15  tháng 12 hằng năm:
# Level 1: 2. Các đơn vị chức năng  có trách nhiệm lưu trữ, bảo quản an toàn các tài liệu
# Level 1: 3. Các đơn vị chức năng trình Hiệu trưởng công bố công khai trên trang thông
# Level 1: HIỆU TRƯỞNG
